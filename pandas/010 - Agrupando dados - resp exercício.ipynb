# %% [markdown]
# - Leia o Dataset de ordens de sanduíche
# - Calcule o valor das contas agrupando por order_id
# - Calcule a quantidade de itens agrupando por order_id

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
arquivo ="/Users/macbookair/Anaconda - Projetos/Python de A a Z - Udemy/DataSets/Sanduiches.txt"
sanduiches = pd.read_table(arquivo)
sanduiches.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
sanduiches.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
sanduiches['item_price1'] = sanduiches.item_price.str.replace('$', '').astype(float)
sanduiches.groupby('order_id').sum().head()
# Out:
#           quantity  item_price1
# order_id
# 1                4        11.56
# 2                2        16.98
# 3                2        12.67
# 4                2        21.00
# 5                2        13.70

# %%
sanduiches.groupby('order_id').count().head()
# Out:
#           quantity  item_name  choice_description  item_price  item_price1
# order_id
# 1                4          4                   2           4            4
# 2                1          1                   1           1            1
# 3                2          2                   1           2            2
# 4                2          2                   2           2            2
# 5                2          2                   1           2            2

# %%
sanduiches.groupby('order_id').item_price1.agg(['count', 'mean', 'min', 'max', 'sum']).head(20)
# Out:
#           count    mean    min    max    sum
# order_id
# 1             4   2.890   2.39   3.39  11.56
# 2             1  16.980  16.98  16.98  16.98
# 3             2   6.335   1.69  10.98  12.67
# 4             2  10.500   9.25  11.75  21.00
# 5             2   6.850   4.45   9.25  13.70
# 6             2   8.750   8.75   8.75  17.50
# 7             2   7.850   4.45  11.25  15.70
# 8             2   5.440   2.39   8.49  10.88
# 9             2   5.335   2.18   8.49  10.67
# 10            2   6.600   4.45   8.75  13.20
# 11            2   6.190   3.39   8.99  12.38
# 12            2   7.185   3.39  10.98  14.37
# 13            2   5.440   2.39   8.49  10.88
# 14            2   5.040   1.09   8.99  10.08
# 15            2   5.440   2.39   8.49  10.88
# 16            2   5.340   1.69   8.99  10.68
# 17            2   5.040   1.09   8.99  10.08
# 18            4   6.225   2.95   8.75  24.90
# 19            2   6.950   2.15  11.75  13.90
# 20            4   9.050   4.45  11.75  36.20
